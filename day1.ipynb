# %%
# Taking user input
name = input("Enter your name: ")
age = input("Enter your age: ")

# Converting age into integer
age = int(age)

# Printing formatted message
print(f"Hello {name}, you are {age} years old.")

# Printing age after 5 years
print(f"In 5 years, you will be {age + 5}.")
# Out:
# Enter your name: vinu
# Enter your age: 56
# Hello vinu, you are 56 years old.
# In 5 years, you will be 61.
